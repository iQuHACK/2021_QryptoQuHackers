# %%
from qutip import *
import numpy as np
import matplotlib.pyplot as plt


from qiskit import Aer

from qiskit_ionq_provider import IonQProvider 

#Call provider and set token value
provider = IonQProvider(token='BFmvdArkiCbsS12r4LZf5VgYDo4HngsS')

# %%
provider.backends()
# Out:
# [<IonQSimulatorBackend('ionq_simulator') from <qiskit_ionq_provider.ionq_provider.IonQProvider object at 0x7f18fd740b10>()>,
#  <IonQQPUBackend('ionq_qpu') from <qiskit_ionq_provider.ionq_provider.IonQProvider object at 0x7f18fd740b10>()>]

# %%
from qiskit import QuantumCircuit

d = 3
bitstring = "1001"
n = len(bitstring)
big_N = 2**n


qc_hash = QuantumCircuit(n+d, n+d)

for index in range(n):
    if int(bitstring[index]):
        qc_hash.x(index)
        
qc_hash.draw()
# Out:
#      ┌───┐
# q_0: ┤ X ├
#      └───┘
# q_1: ─────
#
# q_2: ─────
#      ┌───┐
# q_3: ┤ X ├
#      └───┘
# q_4: ─────
#
# q_5: ─────
#
# q_6: ─────
#
# c: 7/═════

# %%
for i in range(d-1):
    qc_hash.h(n+i)
    
qc_hash.draw()
# Out:
#      ┌───┐
# q_0: ┤ X ├
#      └───┘
# q_1: ─────
#
# q_2: ─────
#      ┌───┐
# q_3: ┤ X ├
#      ├───┤
# q_4: ┤ H ├
#      ├───┤
# q_5: ┤ H ├
#      └───┘
# q_6: ─────
#
# c: 7/═════

# %%
for n_index in range(1,n+1):
    for d_index in range(1,d+1):
        angle_list = []
        for angles_index in range(2**(d_index)):
            angle_list += [4*np.pi * angles_index * 2**(n_index) / big_N]
        
        q_controls = [n_index-1]
        for qcon_index in range(d_index-1):   
            q_controls += [n+qcon_index]
        
        q_target = n+d-1
        
        print(angle_list)
        print(q_controls)
        print(q_target)
        qc_hash.ucrz(angle_list,q_controls,q_target)

qc_hash.draw()
# Out:
# [0.0, 1.5707963267948966]
# [0]
# 6
# [0.0, 1.5707963267948966, 3.141592653589793, 4.71238898038469]
# [0, 4]
# 6
# [0.0, 1.5707963267948966, 3.141592653589793, 4.71238898038469, 6.283185307179586, 7.853981633974483, 9.42477796076938, 10.995574287564276]
# [0, 4, 5]
# 6
# [0.0, 3.141592653589793]
# [1]
# 6
# [0.0, 3.141592653589793, 6.283185307179586, 9.42477796076938]
# [1, 4]
# 6
# [0.0, 3.141592653589793, 6.283185307179586, 9.42477796076938, 12.566370614359172, 15.707963267948966, 18.84955592153876, 21.991148575128552]
# [1, 4, 5]
# 6
# [0.0, 6.283185307179586]
# [2]
# 6
# [0.0, 6.283185307179586, 12.566370614359172, 18.84955592153876]
# [2, 4]
# 6
# [0.0, 6.283185307179586, 12.566370614359172, 18.84955592153876, 25.132741228718345, 31.41592653589793, 37.69911184307752, 43.982297150257104]
# [2, 4, 5]
# 6
# [0.0, 12.566370614359172]
# [3]
# 6
# [0.0, 12.566370614359172, 25.132741228718345, 37.69911184307752]
# [3, 4]
# 6
# ...
